# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split

pd.set_option('display.max_colwidth', None)
pd.set_option('display.max_rows', None)

# %% [markdown]
# ---

# %%
file_path = "../datasets/wadi/WADI.A1_9 Oct 2017/WADI_14days.csv"
df = pd.read_csv(file_path)

# %%
df.head()
# Out:
#    Row       Date            Time  \
# 0    1  9/25/2017  6:00:00.000 PM
# 1    2  9/25/2017  6:00:01.000 PM
# 2    3  9/25/2017  6:00:02.000 PM
# 3    4  9/25/2017  6:00:03.000 PM
# 4    5  9/25/2017  6:00:04.000 PM
#
#    \\WIN-25J4RO10SBF\LOG_DATA\SUTD_WADI\LOG_DATA\1_AIT_001_PV  \
# 0                                                     171.155
# 1                                                     171.155
# 2                                                     171.155
# 3                                                     171.155
# 4                                                     171.155
#
#    \\WIN-25J4RO10SBF\LOG_DATA\SUTD_WADI\LOG_DATA\1_AIT_002_PV  \
# 0                                                    0.619473
# 1                                                    0.619473
# 2                                                    0.619473
# 3                                                    0.607477
# 4                                                    0.607477
#
# ...

# %%
print(df.dtypes)
print(df.shape)
# Out:
# Row                                                                         int64
# Date                                                                       object
# Time                                                                       object
# \\WIN-25J4RO10SBF\LOG_DATA\SUTD_WADI\LOG_DATA\1_AIT_001_PV                float64
# \\WIN-25J4RO10SBF\LOG_DATA\SUTD_WADI\LOG_DATA\1_AIT_002_PV                float64
# \\WIN-25J4RO10SBF\LOG_DATA\SUTD_WADI\LOG_DATA\1_AIT_003_PV                float64
# \\WIN-25J4RO10SBF\LOG_DATA\SUTD_WADI\LOG_DATA\1_AIT_004_PV                float64
# \\WIN-25J4RO10SBF\LOG_DATA\SUTD_WADI\LOG_DATA\1_AIT_005_PV                float64
# \\WIN-25J4RO10SBF\LOG_DATA\SUTD_WADI\LOG_DATA\1_FIT_001_PV                float64
# \\WIN-25J4RO10SBF\LOG_DATA\SUTD_WADI\LOG_DATA\1_LS_001_AL                   int64
# \\WIN-25J4RO10SBF\LOG_DATA\SUTD_WADI\LOG_DATA\1_LS_002_AL                   int64
# ...

# %%
df.drop(["Row", "Date", "Time"], axis=1, inplace=True)
df.head()
# Out:
#    \\WIN-25J4RO10SBF\LOG_DATA\SUTD_WADI\LOG_DATA\1_AIT_001_PV  \
# 0                                                     171.155
# 1                                                     171.155
# 2                                                     171.155
# 3                                                     171.155
# 4                                                     171.155
#
#    \\WIN-25J4RO10SBF\LOG_DATA\SUTD_WADI\LOG_DATA\1_AIT_002_PV  \
# 0                                                    0.619473
# 1                                                    0.619473
# 2                                                    0.619473
# 3                                                    0.607477
# 4                                                    0.607477
#
#    \\WIN-25J4RO10SBF\LOG_DATA\SUTD_WADI\LOG_DATA\1_AIT_003_PV  \
# 0                                                     11.5759
# 1                                                     11.5759
# ...

# %%
print(df.shape)
df.isnull().sum()
# Out:
# (1209601, 127)
# \\WIN-25J4RO10SBF\LOG_DATA\SUTD_WADI\LOG_DATA\1_AIT_001_PV                      0
# \\WIN-25J4RO10SBF\LOG_DATA\SUTD_WADI\LOG_DATA\1_AIT_002_PV                     12
# \\WIN-25J4RO10SBF\LOG_DATA\SUTD_WADI\LOG_DATA\1_AIT_003_PV                      0
# \\WIN-25J4RO10SBF\LOG_DATA\SUTD_WADI\LOG_DATA\1_AIT_004_PV                      6
# \\WIN-25J4RO10SBF\LOG_DATA\SUTD_WADI\LOG_DATA\1_AIT_005_PV                      0
# \\WIN-25J4RO10SBF\LOG_DATA\SUTD_WADI\LOG_DATA\1_FIT_001_PV                      0
# \\WIN-25J4RO10SBF\LOG_DATA\SUTD_WADI\LOG_DATA\1_LS_001_AL                       0
# \\WIN-25J4RO10SBF\LOG_DATA\SUTD_WADI\LOG_DATA\1_LS_002_AL                       0
# \\WIN-25J4RO10SBF\LOG_DATA\SUTD_WADI\LOG_DATA\1_LT_001_PV                       0
# \\WIN-25J4RO10SBF\LOG_DATA\SUTD_WADI\LOG_DATA\1_MV_001_STATUS                   0
# \\WIN-25J4RO10SBF\LOG_DATA\SUTD_WADI\LOG_DATA\1_MV_002_STATUS                   0
# ...

# %%
df.dropna(thresh=df.shape[0]*0.6,how='all', axis=1, inplace=True)

print(df.shape)
df.isnull().sum()
# Out:
# (1209601, 123)
# \\WIN-25J4RO10SBF\LOG_DATA\SUTD_WADI\LOG_DATA\1_AIT_001_PV                 0
# \\WIN-25J4RO10SBF\LOG_DATA\SUTD_WADI\LOG_DATA\1_AIT_002_PV                12
# \\WIN-25J4RO10SBF\LOG_DATA\SUTD_WADI\LOG_DATA\1_AIT_003_PV                 0
# \\WIN-25J4RO10SBF\LOG_DATA\SUTD_WADI\LOG_DATA\1_AIT_004_PV                 6
# \\WIN-25J4RO10SBF\LOG_DATA\SUTD_WADI\LOG_DATA\1_AIT_005_PV                 0
# \\WIN-25J4RO10SBF\LOG_DATA\SUTD_WADI\LOG_DATA\1_FIT_001_PV                 0
# \\WIN-25J4RO10SBF\LOG_DATA\SUTD_WADI\LOG_DATA\1_LS_001_AL                  0
# \\WIN-25J4RO10SBF\LOG_DATA\SUTD_WADI\LOG_DATA\1_LS_002_AL                  0
# \\WIN-25J4RO10SBF\LOG_DATA\SUTD_WADI\LOG_DATA\1_LT_001_PV                  0
# \\WIN-25J4RO10SBF\LOG_DATA\SUTD_WADI\LOG_DATA\1_MV_001_STATUS              0
# \\WIN-25J4RO10SBF\LOG_DATA\SUTD_WADI\LOG_DATA\1_MV_002_STATUS              0
# \\WIN-25J4RO10SBF\LOG_DATA\SUTD_WADI\LOG_DATA\1_MV_003_STATUS              0
# ...

# %%
df.dropna(inplace=True)

print(df.shape)
df.isnull().sum()
# Out:
# (1209551, 123)
# \\WIN-25J4RO10SBF\LOG_DATA\SUTD_WADI\LOG_DATA\1_AIT_001_PV                0
# \\WIN-25J4RO10SBF\LOG_DATA\SUTD_WADI\LOG_DATA\1_AIT_002_PV                0
# \\WIN-25J4RO10SBF\LOG_DATA\SUTD_WADI\LOG_DATA\1_AIT_003_PV                0
# \\WIN-25J4RO10SBF\LOG_DATA\SUTD_WADI\LOG_DATA\1_AIT_004_PV                0
# \\WIN-25J4RO10SBF\LOG_DATA\SUTD_WADI\LOG_DATA\1_AIT_005_PV                0
# \\WIN-25J4RO10SBF\LOG_DATA\SUTD_WADI\LOG_DATA\1_FIT_001_PV                0
# \\WIN-25J4RO10SBF\LOG_DATA\SUTD_WADI\LOG_DATA\1_LS_001_AL                 0
# \\WIN-25J4RO10SBF\LOG_DATA\SUTD_WADI\LOG_DATA\1_LS_002_AL                 0
# \\WIN-25J4RO10SBF\LOG_DATA\SUTD_WADI\LOG_DATA\1_LT_001_PV                 0
# \\WIN-25J4RO10SBF\LOG_DATA\SUTD_WADI\LOG_DATA\1_MV_001_STATUS             0
# \\WIN-25J4RO10SBF\LOG_DATA\SUTD_WADI\LOG_DATA\1_MV_002_STATUS             0
# \\WIN-25J4RO10SBF\LOG_DATA\SUTD_WADI\LOG_DATA\1_MV_003_STATUS             0
# ...

# %% [markdown]
# ---

# %%
val_size = 0.3

train_df, val_test_df = train_test_split(df, test_size=val_size, random_state=42)
val_df, test_df = train_test_split(val_test_df, test_size=0.5, random_state=42)

train_data = train_df.to_numpy()
val_data = val_df.to_numpy()
test_data = test_df.to_numpy()

np.save("../datasets/wadi/wadi_train.npy", train_data)
np.save("../datasets/wadi/wadi_val.npy", val_data)
np.save("../datasets/wadi/wadi_test.npy", test_data)

# %% [markdown]
# ---

# %%
attack_file_path = "../datasets/wadi/WADI.A1_9 Oct 2017/WADI_attackdata.csv"
df = pd.read_csv(attack_file_path)

# %%
df.head()
# Out:
#    Row       Date            Time  \
# 0    1  10/9/2017  6:00:00.000 PM
# 1    2  10/9/2017  6:00:01.000 PM
# 2    3  10/9/2017  6:00:02.000 PM
# 3    4  10/9/2017  6:00:03.000 PM
# 4    5  10/9/2017  6:00:04.000 PM
#
#    \\WIN-25J4RO10SBF\LOG_DATA\SUTD_WADI\LOG_DATA\1_AIT_001_PV  \
# 0                                                      164.21
# 1                                                      164.21
# 2                                                      164.21
# 3                                                      164.21
# 4                                                      164.21
#
#    \\WIN-25J4RO10SBF\LOG_DATA\SUTD_WADI\LOG_DATA\1_AIT_002_PV  \
# 0                                                    0.529486
# 1                                                    0.529486
# 2                                                    0.529486
# 3                                                    0.529486
# 4                                                    0.529486
#
# ...

# %%
df.drop(["Row", "Date", "Time"], axis=1, inplace=True)

print(df.shape)
df.isnull().sum()
# Out:
# (172801, 127)
# \\WIN-25J4RO10SBF\LOG_DATA\SUTD_WADI\LOG_DATA\1_AIT_001_PV                     0
# \\WIN-25J4RO10SBF\LOG_DATA\SUTD_WADI\LOG_DATA\1_AIT_002_PV                     0
# \\WIN-25J4RO10SBF\LOG_DATA\SUTD_WADI\LOG_DATA\1_AIT_003_PV                     0
# \\WIN-25J4RO10SBF\LOG_DATA\SUTD_WADI\LOG_DATA\1_AIT_004_PV                     0
# \\WIN-25J4RO10SBF\LOG_DATA\SUTD_WADI\LOG_DATA\1_AIT_005_PV                     0
# \\WIN-25J4RO10SBF\LOG_DATA\SUTD_WADI\LOG_DATA\1_FIT_001_PV                     0
# \\WIN-25J4RO10SBF\LOG_DATA\SUTD_WADI\LOG_DATA\1_LS_001_AL                      0
# \\WIN-25J4RO10SBF\LOG_DATA\SUTD_WADI\LOG_DATA\1_LS_002_AL                      0
# \\WIN-25J4RO10SBF\LOG_DATA\SUTD_WADI\LOG_DATA\1_LT_001_PV                      0
# \\WIN-25J4RO10SBF\LOG_DATA\SUTD_WADI\LOG_DATA\1_MV_001_STATUS                  0
# \\WIN-25J4RO10SBF\LOG_DATA\SUTD_WADI\LOG_DATA\1_MV_002_STATUS                  0
# ...

# %%
df.dropna(thresh=df.shape[0]*0.6,how='all', axis=1, inplace=True)

print(df.shape)
df.isnull().sum()
# Out:
# (172801, 123)
# \\WIN-25J4RO10SBF\LOG_DATA\SUTD_WADI\LOG_DATA\1_AIT_001_PV                0
# \\WIN-25J4RO10SBF\LOG_DATA\SUTD_WADI\LOG_DATA\1_AIT_002_PV                0
# \\WIN-25J4RO10SBF\LOG_DATA\SUTD_WADI\LOG_DATA\1_AIT_003_PV                0
# \\WIN-25J4RO10SBF\LOG_DATA\SUTD_WADI\LOG_DATA\1_AIT_004_PV                0
# \\WIN-25J4RO10SBF\LOG_DATA\SUTD_WADI\LOG_DATA\1_AIT_005_PV                0
# \\WIN-25J4RO10SBF\LOG_DATA\SUTD_WADI\LOG_DATA\1_FIT_001_PV                0
# \\WIN-25J4RO10SBF\LOG_DATA\SUTD_WADI\LOG_DATA\1_LS_001_AL                 0
# \\WIN-25J4RO10SBF\LOG_DATA\SUTD_WADI\LOG_DATA\1_LS_002_AL                 0
# \\WIN-25J4RO10SBF\LOG_DATA\SUTD_WADI\LOG_DATA\1_LT_001_PV                 0
# \\WIN-25J4RO10SBF\LOG_DATA\SUTD_WADI\LOG_DATA\1_MV_001_STATUS             0
# \\WIN-25J4RO10SBF\LOG_DATA\SUTD_WADI\LOG_DATA\1_MV_002_STATUS             0
# \\WIN-25J4RO10SBF\LOG_DATA\SUTD_WADI\LOG_DATA\1_MV_003_STATUS             0
# ...

# %%
df.dropna(inplace=True)

print(df.shape)
df.isnull().sum()
# Out:
# (172801, 123)
# \\WIN-25J4RO10SBF\LOG_DATA\SUTD_WADI\LOG_DATA\1_AIT_001_PV                0
# \\WIN-25J4RO10SBF\LOG_DATA\SUTD_WADI\LOG_DATA\1_AIT_002_PV                0
# \\WIN-25J4RO10SBF\LOG_DATA\SUTD_WADI\LOG_DATA\1_AIT_003_PV                0
# \\WIN-25J4RO10SBF\LOG_DATA\SUTD_WADI\LOG_DATA\1_AIT_004_PV                0
# \\WIN-25J4RO10SBF\LOG_DATA\SUTD_WADI\LOG_DATA\1_AIT_005_PV                0
# \\WIN-25J4RO10SBF\LOG_DATA\SUTD_WADI\LOG_DATA\1_FIT_001_PV                0
# \\WIN-25J4RO10SBF\LOG_DATA\SUTD_WADI\LOG_DATA\1_LS_001_AL                 0
# \\WIN-25J4RO10SBF\LOG_DATA\SUTD_WADI\LOG_DATA\1_LS_002_AL                 0
# \\WIN-25J4RO10SBF\LOG_DATA\SUTD_WADI\LOG_DATA\1_LT_001_PV                 0
# \\WIN-25J4RO10SBF\LOG_DATA\SUTD_WADI\LOG_DATA\1_MV_001_STATUS             0
# \\WIN-25J4RO10SBF\LOG_DATA\SUTD_WADI\LOG_DATA\1_MV_002_STATUS             0
# \\WIN-25J4RO10SBF\LOG_DATA\SUTD_WADI\LOG_DATA\1_MV_003_STATUS             0
# ...

# %%
attack_data = df.to_numpy()

np.save("../datasets/wadi/wadi_attack.npy", attack_data)
